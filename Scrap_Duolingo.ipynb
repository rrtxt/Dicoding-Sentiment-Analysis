# %% [markdown]
# ### Data Scrapping

# %%
from google_play_scraper import Sort, reviews_all

# %% [markdown]
# com.nianticlabs.monsterhunter

# %%
scrapped_review = reviews_all(
    "com.duolingo",
    lang='en',
    country='us',
    sort=Sort.MOST_RELEVANT,
    count=500
)

# %%
import pandas as pd

df = pd.DataFrame(scrapped_review)
df.rename(columns={"content" : "review"}, inplace=True)
df
# Out:
#                                    reviewId            userName  \
# 0      376629a5-8601-4c51-a2c7-0ba58c919d96           Taiyaki11
# 1      a7a7f3d0-c4e3-46ff-8953-5ebebea3f691      Bearly Edukatd
# 2      92eab6b8-234e-4579-bf30-58883cab7da4       Austin Taylor
# 3      bb541722-0dd6-47ec-bb78-bf5ebad506a1       Pete Stuttgen
# 4      5c187f38-372a-4fe0-8f3c-b19c69cea3e0     ASHLEY RUTLEDGE
# ...                                     ...                 ...
# 11995  25e1c4f5-eabf-494a-875a-a82d0c366569  kevin lyle varquez
# 11996  9d77bd87-7cbf-4808-b031-5a26cdd9a8e6       Jared Morales
# 11997  0ae874f8-a728-4ebc-a859-b59e7bea05e9         Jian Hui Wu
# 11998  867d95ad-2ae5-46f1-bbf3-ca92bd6e4a1c         The Trouble
# 11999  81077c62-ce23-4aa5-9be7-1257fe0cd1f1     Austin Topolski
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/a-/ALV-U...
# 1      https://play-lh.googleusercontent.com/a-/ALV-U...
# ...

# %%
df.to_csv("./dataset/mhnow_review_en.csv", index=False)
df.head()
# Out:
#                                reviewId         userName  \
# 0  376629a5-8601-4c51-a2c7-0ba58c919d96        Taiyaki11
# 1  a7a7f3d0-c4e3-46ff-8953-5ebebea3f691   Bearly Edukatd
# 2  92eab6b8-234e-4579-bf30-58883cab7da4    Austin Taylor
# 3  bb541722-0dd6-47ec-bb78-bf5ebad506a1    Pete Stuttgen
# 4  5c187f38-372a-4fe0-8f3c-b19c69cea3e0  ASHLEY RUTLEDGE
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2  https://play-lh.googleusercontent.com/a-/ALV-U...
# 3  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                               review  score  thumbsUpCount  \
# 0  later level play is absolutely beyond ridiculo...      2              4
# 1  I love how much this game lags and crashes, yo...      2             25
# ...
